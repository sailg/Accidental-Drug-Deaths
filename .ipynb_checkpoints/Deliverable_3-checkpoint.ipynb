# %% [markdown]
# <a href="https://colab.research.google.com/github/sailg/Accidental-Drug-Deaths/blob/main/Deliverable_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Accidental Drug Deaths....

# %% [markdown]
# ### Source : https://catalog.data.gov/dataset/accidental-drug-related-deaths-january-2012-sept-2015

# %% [markdown]
# ### Q1.What is your issue of interest (provide sufficient background information)?

# %% [markdown]
# "Accidental deaths due to various drugs"

# %% [markdown]
# ### Q2.Why is this issue important to you and/or to others?

# %% [markdown]
#  I found this dataset as challenging and thought would help me putting everything I have learnt from this class to complete this project.Also this analysis might lead  to decrease deaths due to drugs

# %% [markdown]
# ### Q.3 What questions do you have in mind and would like to answer?

# %% [markdown]
# - "Which age group are facing deaths at most?"
# - "Which gender group facing more deaths?"
# - "Which drug is reason for more deaths"

# %% [markdown]
# ### Q.4 Where do you get the data to help answer your questions?
#
#     Source: https://catalog.data.gov/dataset/accidental-drug-related-deaths-january-2012-sept-2015

# %% [markdown]
# ### Q.5 What will be your unit of analysis (for example, patient, organization, or country)? Roughly how many units (observations) do you expect to analyze?
#
# My unit of analysis is deaths recorded due to different kind of drugs.

# %% [markdown]
# ### Q.6 What variables/measures do you plan to use in your analysis (variables should be tied to the questions in #3)?
#
#
# "Age","Gender","Drug name"

# %% [markdown]
# ### Q.7 What kinds of techniques do you plan to use (for example, summary statistics, scatter plot, bar chart, chi-squared test)?¶
#
#
# "Bar plot"

# %% [markdown]
# ### Importing required Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 5, 10
import numpy as np

# %% [markdown]
# ### Loading CSV file as a dataframe

# %%
df=pd.read_csv("source.csv")

# %% [markdown]
# ### Exploring Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5102 entries, 1 to 5104
# Data columns (total 34 columns):
# ID                     5102 non-null object
# Date                   5101 non-null object
# DateType               5101 non-null object
# Age                    5102 non-null float64
# Sex                    5099 non-null object
# Race                   5092 non-null object
# ResidenceCity          4932 non-null object
# ResidenceCounty        4308 non-null object
# ResidenceState         3556 non-null object
# DeathCity              5100 non-null object
# DeathCounty            4005 non-null object
# Location               5081 non-null object
# LocationifOther        590 non-null object
# DescriptionofInjury    4324 non-null object
# InjuryPlace            5037 non-null object
# InjuryCity             3348 non-null object
# InjuryCounty           2363 non-null object
# InjuryState            1423 non-null object
# COD                    5102 non-null object
# ...

# %%
df.head()
# Out:
#         ID                    Date      DateType   Age     Sex          Race  \
# 0  14-0273  06/28/2014 12:00:00 AM  DateReported   NaN     NaN           NaN
# 1  13-0102  03/21/2013 12:00:00 AM   DateofDeath  48.0    Male         Black
# 2  16-0165  03/13/2016 12:00:00 AM   DateofDeath  30.0  Female         White
# 3  16-0208  03/31/2016 12:00:00 AM   DateofDeath  23.0    Male         White
# 4  13-0052  02/13/2013 12:00:00 AM   DateofDeath  22.0    Male  Asian, Other
#
#   ResidenceCity ResidenceCounty ResidenceState  DeathCity  ... Tramad  \
# 0           NaN             NaN            NaN        NaN  ...    NaN
# 1       NORWALK             NaN            NaN    NORWALK  ...    NaN
# 2    SANDY HOOK       FAIRFIELD             CT    DANBURY  ...    NaN
# 3           RYE     WESTCHESTER             NY  GREENWICH  ...    NaN
# 4      FLUSHING          QUEENS            NaN  GREENWICH  ...    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# ...

# %%
df.isna().sum()
# Out:
# ID                        0
# Date                      1
# DateType                  1
# Age                       0
# Sex                       3
# Race                     10
# ResidenceCity           170
# ResidenceCounty         794
# ResidenceState         1546
# DeathCity                 2
# DeathCounty            1097
# Location                 21
# LocationifOther        4512
# DescriptionofInjury     778
# InjuryPlace              65
# InjuryCity             1754
# InjuryCounty           2739
# InjuryState            3679
# COD                       0
# Heroin                 2573
# Cocaine                3582
# Fentanyl               2872
# FentanylAnalogue       4713
# Oxycodone              4495
# Oxymorphone            4994
# Ethanol                3855
# Hydrocodone            4985
# Benzodiazepine         3760
# Methadone              4628
# Amphet                 4943
# Tramad                 4972
# Morphine_NotHeroin     5060
# Hydromorphone          5077
# ...

# %% [markdown]
# ### Transposing dataframe for clear view of available columns

# %%
df.head().T
# Out:
#                                                         0  \
# ID                                                14-0273
# Date                               06/28/2014 12:00:00 AM
# DateType                                     DateReported
# Age                                                   NaN
# Sex                                                   NaN
# Race                                                  NaN
# ResidenceCity                                         NaN
# ResidenceCounty                                       NaN
# ResidenceState                                        NaN
# DeathCity                                             NaN
# DeathCounty                                           NaN
# Location                                              NaN
# LocationifOther                                       NaN
# DescriptionofInjury                             substance
# InjuryPlace                                           NaN
# ...

# %% [markdown]
# ### Dropping unwanted columns

# %%
df=df.drop(["ResidenceCityGeo","InjuryCityGeo","DeathCityGeo","OtherSignifican","OpiateNOS","AnyOpioid","Other"],axis=1)

# %%
df.shape
# Out:
# (5105, 34)

# %% [markdown]
# ### List of columns

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'DateType', 'Age', 'Sex', 'Race', 'ResidenceCity',
#        'ResidenceCounty', 'ResidenceState', 'DeathCity', 'DeathCounty',
#        'Location', 'LocationifOther', 'DescriptionofInjury', 'InjuryPlace',
#        'InjuryCity', 'InjuryCounty', 'InjuryState', 'COD', 'Heroin', 'Cocaine',
#        'Fentanyl', 'FentanylAnalogue', 'Oxycodone', 'Oxymorphone', 'Ethanol',
#        'Hydrocodone', 'Benzodiazepine', 'Methadone', 'Amphet', 'Tramad',
#        'Morphine_NotHeroin', 'Hydromorphone', 'MannerofDeath'],
#       dtype='object')

# %% [markdown]
# ### Different kinds of drugs are aligned as column names

# %% [markdown]
# ### For further usage of those drug names they are extracted as below in to a list

# %%
df
# Out:
#            ID                    Date      DateType   Age     Sex  \
# 1     13-0102  03/21/2013 12:00:00 AM   DateofDeath  48.0    Male
# 2     16-0165  03/13/2016 12:00:00 AM   DateofDeath  30.0  Female
# 3     16-0208  03/31/2016 12:00:00 AM   DateofDeath  23.0    Male
# 4     13-0052  02/13/2013 12:00:00 AM   DateofDeath  22.0    Male
# 5     14-0277  06/29/2014 12:00:00 AM   DateofDeath  23.0    Male
# ...       ...                     ...           ...   ...     ...
# 5100  15-0466  09/08/2015 12:00:00 AM  DateReported  43.0    Male
# 5101  17-0618  07/22/2017 12:00:00 AM  DateReported  21.0    Male
# 5102  18-0646  08/14/2018 12:00:00 AM   DateofDeath  30.0    Male
# 5103  14-0124  03/16/2014 12:00:00 AM   DateofDeath  33.0    Male
# 5104  16-0637  09/15/2016 12:00:00 AM   DateofDeath  33.0    Male
#
#               Race  ResidenceCity ResidenceCounty ResidenceState  DeathCity  \
# 1            Black        NORWALK             NaN            NaN    NORWALK
# ...

# %% [markdown]
# Every column contains at least a NULL Value. So droping NULL values individually for each column where neccesaary

# %% [markdown]
# Updating dataframe without null values in Age column

# %%
df = df[df['Age'].notna()]

# %%
df.head()
# Out:
#         ID                    Date     DateType   Age     Sex          Race  \
# 1  13-0102  03/21/2013 12:00:00 AM  DateofDeath  48.0    Male         Black
# 2  16-0165  03/13/2016 12:00:00 AM  DateofDeath  30.0  Female         White
# 3  16-0208  03/31/2016 12:00:00 AM  DateofDeath  23.0    Male         White
# 4  13-0052  02/13/2013 12:00:00 AM  DateofDeath  22.0    Male  Asian, Other
# 5  14-0277  06/29/2014 12:00:00 AM  DateofDeath  23.0    Male         White
#
#   ResidenceCity ResidenceCounty ResidenceState  DeathCity  ... Oxymorphone  \
# 1       NORWALK             NaN            NaN    NORWALK  ...         NaN
# 2    SANDY HOOK       FAIRFIELD             CT    DANBURY  ...         NaN
# 3           RYE     WESTCHESTER             NY  GREENWICH  ...         NaN
# 4      FLUSHING          QUEENS            NaN  GREENWICH  ...         NaN
# 5       BRISTOL             NaN            NaN    BRISTOL  ...         NaN
#
# ...

# %% [markdown]
# ## "Which age group are facing deaths at most?"

# %%
plt.figure(figsize=(20,10))
bins= [15,25,35,45,55,65,75,85]
plt.hist(df.Age, bins=bins, edgecolor="k")
plt.xticks(bins,fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("Age Intervals",fontsize=30)
plt.ylabel("Number of deaths",fontsize=30)
my_colors = 'rgbkymc'
plt.show()

# %% [markdown]
# People between age 45-55 are facing lot of deaths due to drugs. 25-35 age group comes next with a slight difference in accidental deaths due to drugs

# %%
df.head(1)
# Out:
#         ID                    Date     DateType   Age   Sex   Race  \
# 1  13-0102  03/21/2013 12:00:00 AM  DateofDeath  48.0  Male  Black
#
#   ResidenceCity ResidenceCounty ResidenceState DeathCity  ... Oxymorphone  \
# 1       NORWALK             NaN            NaN   NORWALK  ...         NaN
#
#   Ethanol Hydrocodone Benzodiazepine Methadone Amphet Tramad  \
# 1     NaN         NaN            NaN       NaN    NaN    NaN
#
#   Morphine_NotHeroin Hydromorphone MannerofDeath
# 1                NaN           NaN      Accident
#
# [1 rows x 34 columns]

# %% [markdown]
# ## "Which gender group facing more deaths?"

# %%
sns.countplot(x="Sex", data=df)

# %% [markdown]
# From this graph we can clearly say that Males are facing more accidental deaths due to drugs than females.

# %% [markdown]
# ### "Which drug is reason for more deaths ?"

# %%
list_drugs=list(df.columns[19:33]) # creating a list of drugs

# %%
drug_dict={}
for drug in list_drugs:
    count=df[drug].notna().sum()
    drug_dict[drug]=count
drug_dict
# Out:
# {'Heroin': 2529,
#  'Cocaine': 1520,
#  'Fentanyl': 2230,
#  'FentanylAnalogue': 389,
#  'Oxycodone': 607,
#  'Oxymorphone': 108,
#  'Ethanol': 1247,
#  'Hydrocodone': 117,
#  'Benzodiazepine': 1342,
#  'Methadone': 474,
#  'Amphet': 159,
#  'Tramad': 130,
#  'Morphine_NotHeroin': 42,
#  'Hydromorphone': 25}

# %%
# Plotting Drug deaths Graph
plt.figure(figsize=(20,10))
names = list(drug_dict.keys())
values = list(drug_dict.values())
plt.bar(range(len(drug_dict)),values,tick_label=names) #tick_label does the some work as plt.xticks()
plt.xlabel("Drug type",fontsize=20)
plt.ylabel('Number of deaths',fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20,rotation=90)
plt.show()

# %% [markdown]
# Heroine and Cocaine are the drugs that caused more accidental deaths

# %% [markdown]
# # THE END
